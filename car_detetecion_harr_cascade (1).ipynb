# %%
import cv2
print(cv2.__version__)

cascade_src = 'D:\\datasets\\opencv-master\\data\\haarcascades\\cars.xml'
#video_src = 'C:\\Users\\Naman\\Downloads\\Compressed\\vehicle_detection_haarcascades-master\\vehicle_detection_haarcascades-master\\dataset\\video1.avi'
#video_src = "D:\\datasets\\example1.mp4"
video_src = 'C:\\Users\\Naman\\Downloads\\Compressed\\vehicle_detection_haarcascades-master\\vehicle_detection_haarcascades-master\\dataset\\video2.avi'
font = cv2.FONT_HERSHEY_SIMPLEX
cap = cv2.VideoCapture(video_src)
car_cascade = cv2.CascadeClassifier(cascade_src)
total_cars = 0
flag = 19
while True:
    flag += 1
    ret, img = cap.read()
    if (type(img) == type(None)):
        break
   # print(img.shape)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #img=cv2.resize(img,(400,400))
    cars = car_cascade.detectMultiScale(gray, 1.1, 1)

    for (x,y,w,h) in cars:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
        cv2.line(img,(0,80),(300,80),(255,0,0),2)
        center_x = (x+(x+w)) //2
        center_y = (y+(y+h)) // 2
        print("outside the loop",center_y)
        cv2.circle(img,(center_x,center_y),2,(255,0,0),-1)
        if center_y ==80:
            total_cars += 1
            print("inside the loop\n\n\n",center_y)
    
    cv2.putText(img,str(total_cars),(0,50), font, 2, (0,0,255), 3, cv2.LINE_AA)
    
    cv2.imshow('video', img)
    
    if cv2.waitKey(33) == 27:
        break

cv2.destroyAllWindows()
# Out:
# 4.1.0
# outside the loop 34
# outside the loop 42
# outside the loop 78
# outside the loop 114
# outside the loop 78
# outside the loop 115
# outside the loop 34
# outside the loop 42
# outside the loop 79
# outside the loop 111
# outside the loop 34
# outside the loop 40
# outside the loop 43
# outside the loop 79
# outside the loop 112
# outside the loop 34
# outside the loop 41
# outside the loop 43
# outside the loop 103
# outside the loop 45
# outside the loop 34
# outside the loop 41
# outside the loop 108
# outside the loop 77
# outside the loop 108
# outside the loop 75
# outside the loop 35
# outside the loop 45
# outside the loop 26
# outside the loop 106
# outside the loop 74
# outside the loop 77
# outside the loop 35
# outside the loop 45
# outside the loop 38
# outside the loop 27
# outside the loop 75
# outside the loop 104
# outside the loop 35
# outside the loop 45
# outside the loop 26
# outside the loop 36
# outside the loop 95
# outside the loop 104
# outside the loop 37
# outside the loop 45
# outside the loop 70
# outside the loop 36
# outside the loop 100
# outside the loop 38
# outside the loop 45
# outside the loop 26
# outside the loop 70
# outside the loop 37
# outside the loop 92
# outside the loop 37
# outside the loop 98
# outside the loop 48
# outside the loop 27
# outside the loop 37
# outside the loop 96
# outside the loop 37
# outside the loop 90
# outside the loop 46
# outside the loop 37
# outside the loop 28
# outside the loop 37
# outside the loop 47
# outside the loop 95
# outside the loop 89
# outside the loop 94
# outside the loop 38
# outside the loop 50
# outside the loop 37
# outside the loop 87
# outside the loop 29
# outside the loop 70
# outside the loop 38
# outside the loop 93
# outside the loop 49
# outside the loop 90
# outside the loop 39
# outside the loop 38
# outside the loop 49
# outside the loop 35
# outside the loop 90
# outside the loop 39
# outside the loop 49
# outside the loop 35
# outside the loop 89
# outside the loop 40
# outside the loop 51
# outside the loop 83
# outside the loop 87
# outside the loop 35
# outside the loop 39
# outside the loop 40
# outside the loop 51
# outside the loop 54
# outside the loop 81
# outside the loop 87
# outside the loop 180
# outside the loop 35
# outside the loop 40
# outside the loop 51
# outside the loop 78
# outside the loop 84
# outside the loop 41
# outside the loop 51
# outside the loop 78
# outside the loop 180
# outside the loop 83
# outside the loop 41
# outside the loop 53
# outside the loop 61
# outside the loop 77
# outside the loop 81
# outside the loop 33
# outside the loop 42
# outside the loop 55
# outside the loop 34
# outside the loop 76
# outside the loop 82
# outside the loop 74
# outside the loop 43
# outside the loop 54
# outside the loop 32
# outside the loop 81
# outside the loop 168
# outside the loop 44
# outside the loop 55
# outside the loop 32
# outside the loop 75
# outside the loop 78
# outside the loop 43
# outside the loop 58
# outside the loop 59
# outside the loop 32
# outside the loop 77
# outside the loop 160
# outside the loop 44
# outside the loop 75
# outside the loop 157
# outside the loop 45
# outside the loop 55
# outside the loop 75
# outside the loop 156
# outside the loop 32
# outside the loop 46
# outside the loop 57
# outside the loop 31
# outside the loop 69
# outside the loop 59
# outside the loop 156
# outside the loop 73
# outside the loop 70
# outside the loop 73
# outside the loop 153
# outside the loop 68
# outside the loop 74
# outside the loop 60
# outside the loop 67
# outside the loop 30
# outside the loop 33
# outside the loop 145
# outside the loop 61
# outside the loop 71
# outside the loop 30
# outside the loop 63
# outside the loop 142
# outside the loop 69
# outside the loop 65
# outside the loop 63
# outside the loop 69
# outside the loop 137
# outside the loop 68
# outside the loop 139
# outside the loop 50
# outside the loop 64
# outside the loop 27
# outside the loop 35
# outside the loop 136
# outside the loop 68
# outside the loop 64
# outside the loop 28
# outside the loop 68
# outside the loop 36
# outside the loop 133
# outside the loop 66
# outside the loop 65
# outside the loop 53
# outside the loop 61
# outside the loop 29
# outside the loop 35
# outside the loop 130
# outside the loop 51
# outside the loop 67
# outside the loop 65
# outside the loop 54
# outside the loop 29
# outside the loop 61
# outside the loop 37
# outside the loop 65
# outside the loop 130
# outside the loop 66
# outside the loop 54
# outside the loop 59
# outside the loop 126
# outside the loop 63
# outside the loop 37
# outside the loop 56
# outside the loop 64
# outside the loop 68
# outside the loop 60
# outside the loop 56
# outside the loop 58
# outside the loop 62
# outside the loop 69
# outside the loop 58
# outside the loop 27
# outside the loop 122
# outside the loop 70
# outside the loop 61
# outside the loop 57
# outside the loop 57
# outside the loop 120
# outside the loop 60
# outside the loop 71
# outside the loop 56
# outside the loop 61
# outside the loop 74
# outside the loop 116
# outside the loop 38
# outside the loop 58
# outside the loop 60
# outside the loop 114
# outside the loop 74
# outside the loop 40
# outside the loop 59
# outside the loop 113
# outside the loop 39
# outside the loop 57
# outside the loop 61
# outside the loop 26
# outside the loop 40
# outside the loop 62
# outside the loop 77
# outside the loop 53
# outside the loop 61
# outside the loop 108
# outside the loop 61
# outside the loop 107
# outside the loop 79
# outside the loop 64
# outside the loop 107
# outside the loop 81
# outside the loop 42
# outside the loop 52
# outside the loop 65
# outside the loop 104
# outside the loop 81
# outside the loop 43
# outside the loop 64
# outside the loop 50
# outside the loop 82
# outside the loop 102
# outside the loop 65
# outside the loop 83
# outside the loop 50
# outside the loop 53
# outside the loop 100
# outside the loop 68
# outside the loop 84
# outside the loop 43
# outside the loop 99
# outside the loop 54
# outside the loop 68
# outside the loop 86
# outside the loop 44
# outside the loop 98
# outside the loop 48
# outside the loop 23
# outside the loop 70
# outside the loop 87
# outside the loop 48
# outside the loop 95
# outside the loop 70
# outside the loop 48
# outside the loop 44
# outside the loop 53
# outside the loop 89
# outside the loop 94
# outside the loop 205
# outside the loop 46
# outside the loop 46
# outside the loop 91
# outside the loop 93
# outside the loop 45
# outside the loop 192
# outside the loop 46
# outside the loop 71
# outside the loop 53
# outside the loop 92
# outside the loop 186
# outside the loop 92
# outside the loop 46
# outside the loop 93
# outside the loop 90
# outside the loop 50
# outside the loop 190
# outside the loop 181
# outside the loop 89
# outside the loop 48
# outside the loop 49
# outside the loop 43
# outside the loop 43
# outside the loop 51
# outside the loop 44
# outside the loop 87
# outside the loop 94
# outside the loop 177
# outside the loop 87
# outside the loop 47
# outside the loop 98
# outside the loop 49
# outside the loop 22
# outside the loop 43
# outside the loop 47
# outside the loop 87
# outside the loop 85
# outside the loop 99
# outside the loop 21
# outside the loop 83
# outside the loop 173
# outside the loop 165
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 48
# outside the loop 83
# outside the loop 48
# outside the loop 21
# outside the loop 82
# outside the loop 82
# outside the loop 84
# outside the loop 50
# outside the loop 47
# outside the loop 20
# outside the loop 21
# outside the loop 83
# outside the loop 81
# outside the loop 158
# outside the loop 49
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 155
# outside the loop 85
# outside the loop 42
# outside the loop 47
# outside the loop 47
# outside the loop 197
# outside the loop 79
# outside the loop 152
# outside the loop 87
# outside the loop 46
# outside the loop 48
# outside the loop 21
# outside the loop 150
# outside the loop 188
# outside the loop 78
# outside the loop 87
# outside the loop 47
# outside the loop 77
# outside the loop 187
# outside the loop 151
# outside the loop 89
# outside the loop 52
# outside the loop 19
# outside the loop 76
# outside the loop 144
# outside the loop 184
# outside the loop 40
# outside the loop 90
# outside the loop 40
# outside the loop 49
# outside the loop 20
# outside the loop 22
# outside the loop 180
# outside the loop 75
# outside the loop 143
# outside the loop 164
# outside the loop 92
# outside the loop 51
# outside the loop 20
# outside the loop 75
# outside the loop 175
# outside the loop 139
# outside the loop 93
# outside the loop 43
# outside the loop 51
# outside the loop 18
# outside the loop 55
# outside the loop 74
# outside the loop 138
# outside the loop 37
# outside the loop 168
# outside the loop 44
# outside the loop 94
# outside the loop 51
# outside the loop 165
# outside the loop 72
# outside the loop 136
# outside the loop 37
# outside the loop 42
# outside the loop 24
# outside the loop 17
# outside the loop 163
# outside the loop 71
# outside the loop 42
# outside the loop 97
# outside the loop 55
# outside the loop 24
# outside the loop 102
# outside the loop 54
# outside the loop 18
# outside the loop 71
# outside the loop 160
# outside the loop 129
# outside the loop 20
# outside the loop 71
# outside the loop 126
# outside the loop 155
# outside the loop 146
# outside the loop 102
# outside the loop 40
# outside the loop 58
# outside the loop 55
# outside the loop 20
# outside the loop 24
# outside the loop 17
# outside the loop 68
# outside the loop 125
# outside the loop 151
# outside the loop 102
# outside the loop 40
# outside the loop 55
# outside the loop 61
# outside the loop 69
# outside the loop 124
# outside the loop 148
# outside the loop 37
# outside the loop 61
# outside the loop 26
# outside the loop 66
# outside the loop 60
# outside the loop 146
# outside the loop 37
# outside the loop 144
# outside the loop 119
# outside the loop 36
# outside the loop 39
# outside the loop 57
# outside the loop 27
# outside the loop 67
# outside the loop 17
# outside the loop 141
# outside the loop 115
# outside the loop 36
# outside the loop 58
# outside the loop 116
# outside the loop 27
# outside the loop 140
# outside the loop 136
# outside the loop 37
# outside the loop 116
# outside the loop 59
# outside the loop 18
# outside the loop 27
# outside the loop 65
# outside the loop 36
# outside the loop 120
# outside the loop 135
# outside the loop 64
# outside the loop 25
# outside the loop 114
# outside the loop 59
# outside the loop 128
# outside the loop 18
# outside the loop 27
# outside the loop 65
# outside the loop 37
# outside the loop 114
# outside the loop 121
# outside the loop 132
# outside the loop 64
# outside the loop 26
# outside the loop 125
# outside the loop 33
# outside the loop 16
# outside the loop 38
# outside the loop 124
# outside the loop 131
# outside the loop 111
# outside the loop 125
# outside the loop 29
# outside the loop 127
# outside the loop 128
# outside the loop 64
# outside the loop 107
# outside the loop 34
# outside the loop 29
# outside the loop 67
# outside the loop 126
# outside the loop 108
# outside the loop 35
# outside the loop 60
# outside the loop 29
# outside the loop 68
# outside the loop 61
# outside the loop 107
# outside the loop 33
# outside the loop 121
# outside the loop 16
# outside the loop 61
# outside the loop 29
# outside the loop 70
# outside the loop 34
# outside the loop 120
# outside the loop 67
# outside the loop 104
# outside the loop 16
# outside the loop 29
# outside the loop 70
# outside the loop 118
# outside the loop 34
# outside the loop 102
# outside the loop 62
# outside the loop 15
# outside the loop 59
# outside the loop 29
# outside the loop 33
# outside the loop 194
# outside the loop 72
# outside the loop 115
# outside the loop 69
# outside the loop 26
# outside the loop 100
# outside the loop 15
# outside the loop 192
# outside the loop 101
# outside the loop 69
# outside the loop 113
# outside the loop 33
# outside the loop 26
# outside the loop 74
# outside the loop 113
# outside the loop 33
# outside the loop 186
# outside the loop 31
# outside the loop 98
# outside the loop 30
# outside the loop 74
# outside the loop 112
# outside the loop 182
# outside the loop 32
# outside the loop 69
# outside the loop 27
# outside the loop 95
# outside the loop 110
# outside the loop 27
# outside the loop 180
# outside the loop 30
# outside the loop 95
# outside the loop 102
# outside the loop 31
# outside the loop 76
# outside the loop 107
# outside the loop 178
# outside the loop 30
# outside the loop 94
# outside the loop 56
# outside the loop 14
# outside the loop 32
# outside the loop 103
# outside the loop 174
# outside the loop 69
# outside the loop 91
# outside the loop 29
# outside the loop 14
# outside the loop 54
# outside the loop 31
# outside the loop 88
# outside the loop 103
# outside the loop 169
# outside the loop 31
# outside the loop 14
# outside the loop 54
# outside the loop 32
# outside the loop 101
# outside the loop 77
# outside the loop 167
# outside the loop 163
# outside the loop 90
# outside the loop 54
# outside the loop 13
# outside the loop 31
# outside the loop 32
# outside the loop 79
# outside the loop 162
# outside the loop 29
# outside the loop 89
# outside the loop 101
# outside the loop 96
# outside the loop 52
# outside the loop 32
# outside the loop 159
# outside the loop 29
# outside the loop 88
# outside the loop 98
# outside the loop 33
# outside the loop 81
# outside the loop 29
# outside the loop 86
# outside the loop 157
# outside the loop 81
# outside the loop 96
# outside the loop 30
# outside the loop 83
# outside the loop 153
# outside the loop 77
# outside the loop 34
# outside the loop 51
# outside the loop 93
# outside the loop 13
# outside the loop 30
# outside the loop 82
# outside the loop 84
# outside the loop 151
# outside the loop 34
# outside the loop 94
# outside the loop 30
# outside the loop 82
# outside the loop 34
# outside the loop 146
# outside the loop 83
# outside the loop 91
# outside the loop 29
# outside the loop 13
# outside the loop 34
# outside the loop 144
# outside the loop 79
# outside the loop 90
# outside the loop 49
# outside the loop 12
# outside the loop 34
# outside the loop 50
# outside the loop 29
# outside the loop 141
# outside the loop 82
# outside the loop 88
# outside the loop 78
# outside the loop 79
# outside the loop 90
# outside the loop 14
# outside the loop 28
# outside the loop 139
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 35
# outside the loop 49
# outside the loop 88
# outside the loop 82
# outside the loop 12
# outside the loop 28
# outside the loop 82
# outside the loop 135
# outside the loop 86
# outside the loop 35
# outside the loop 78
# outside the loop 85
# outside the loop 45
# outside the loop 90
# outside the loop 28
# outside the loop 78
# outside the loop 84
# outside the loop 133
# outside the loop 35
# outside the loop 89
# outside the loop 48
# outside the loop 12
# outside the loop 27
# outside the loop 78
# outside the loop 81
# outside the loop 36
# outside the loop 74
# outside the loop 128
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 93
# outside the loop 36
# outside the loop 47
# outside the loop 26
# outside the loop 79
# outside the loop 129
# outside the loop 81
# outside the loop 74
# outside the loop 43
# outside the loop 119
# outside the loop 75
# outside the loop 84
# outside the loop 95
# outside the loop 81
# outside the loop 74
# outside the loop 36
# outside the loop 126
# outside the loop 34
# outside the loop 97
# outside the loop 76
# outside the loop 81
# outside the loop 122
# outside the loop 72
# outside the loop 75
# outside the loop 37
# outside the loop 99
# outside the loop 12
# outside the loop 46
# outside the loop 38
# outside the loop 73
# outside the loop 122
# outside the loop 78
# outside the loop 100
# outside the loop 25
# outside the loop 74
# outside the loop 77
# outside the loop 121
# outside the loop 31
# outside the loop 39
# outside the loop 45
# outside the loop 74
# outside the loop 79
# outside the loop 116
# outside the loop 67
# outside the loop 38
# outside the loop 87
# outside the loop 12
# outside the loop 24
# outside the loop 78
# outside the loop 69
# outside the loop 115
# outside the loop 73
# outside the loop 38
# outside the loop 43
# outside the loop 11
# outside the loop 111
# outside the loop 115
# outside the loop 75
# outside the loop 69
# outside the loop 43
# outside the loop 38
# outside the loop 24
# outside the loop 72
# outside the loop 74
# outside the loop 112
# outside the loop 39
# outside the loop 42
# outside the loop 74
# outside the loop 110
# outside the loop 40
# outside the loop 65
# outside the loop 23
# outside the loop 73
# outside the loop 107
# outside the loop 64
# outside the loop 40
# outside the loop 19
# outside the loop 23
# outside the loop 107
# outside the loop 64
# outside the loop 71
# outside the loop 41
# outside the loop 100
# outside the loop 63
# outside the loop 68
# outside the loop 96
# outside the loop 38
# outside the loop 104
# outside the loop 41
# outside the loop 41
# outside the loop 27
# outside the loop 103
# outside the loop 71
# outside the loop 67
# outside the loop 38
# outside the loop 42
# outside the loop 42
# outside the loop 58
# outside the loop 19
# outside the loop 11
# outside the loop 70
# outside the loop 101
# outside the loop 62
# outside the loop 64
# outside the loop 39
# outside the loop 42
# outside the loop 41
# outside the loop 11
# outside the loop 64
# outside the loop 69
# outside the loop 101
# outside the loop 65
# outside the loop 42
# outside the loop 41
# outside the loop 22
# outside the loop 31
# outside the loop 67
# outside the loop 97
# outside the loop 42
# outside the loop 60
# outside the loop 23
# outside the loop 91
# outside the loop 40
# outside the loop 97
# outside the loop 43
# outside the loop 60
# outside the loop 20
# outside the loop 22
# outside the loop 67
# outside the loop 31
# outside the loop 61
# outside the loop 43
# outside the loop 94
# outside the loop 66
# outside the loop 28
# outside the loop 62
# outside the loop 93
# outside the loop 44
# outside the loop 64
# outside the loop 28
# outside the loop 31
# outside the loop 91
# outside the loop 45
# outside the loop 54
# outside the loop 63
# outside the loop 89
# outside the loop 33
# outside the loop 45
# outside the loop 21
# outside the loop 29
# outside the loop 33
# outside the loop 86
# outside the loop 42
# outside the loop 45
# outside the loop 19
# outside the loop 29
# outside the loop 32
# outside the loop 88
# outside the loop 86
# outside the loop 45
# outside the loop 29
# outside the loop 33
# outside the loop 86
# outside the loop 46
# outside the loop 19
# outside the loop 30
# outside the loop 84
# outside the loop 33
# outside the loop 46
# outside the loop 19
# outside the loop 29
# outside the loop 59
# outside the loop 83
# outside the loop 43
# outside the loop 34
# outside the loop 46
# outside the loop 59
# outside the loop 29
# outside the loop 82
# outside the loop 48
# outside the loop 51
# outside the loop 35
# outside the loop 35
# outside the loop 18
# outside the loop 31
# outside the loop 34
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 48
# outside the loop 18
# outside the loop 30
# outside the loop 79
# outside the loop 35
# outside the loop 35
# outside the loop 48
# outside the loop 50
# outside the loop 31
# outside the loop 55
# outside the loop 19
# outside the loop 34
# outside the loop 78
# outside the loop 48
# outside the loop 17
# outside the loop 32
# outside the loop 77
# outside the loop 35
# outside the loop 46
# outside the loop 50
# outside the loop 48
# outside the loop 32
# outside the loop 18
# outside the loop 34
# outside the loop 50
# outside the loop 76
# outside the loop 49
# outside the loop 17
# outside the loop 32
# outside the loop 74
# outside the loop 35
# outside the loop 33
# outside the loop 50
# outside the loop 49
# outside the loop 18
# outside the loop 25
# outside the loop 31
# outside the loop 74
# outside the loop 35
# outside the loop 50
# outside the loop 32
# outside the loop 73
# outside the loop 35
# outside the loop 204
# outside the loop 51
# outside the loop 49
# outside the loop 16
# outside the loop 32
# outside the loop 73
# outside the loop 36
# outside the loop 197
# outside the loop 52
# outside the loop 45
# outside the loop 14
# outside the loop 53
# outside the loop 33
# outside the loop 71
# outside the loop 36
# outside the loop 189
# outside the loop 18
# outside the loop 33
# outside the loop 71
# outside the loop 183
# outside the loop 47
# outside the loop 37
# outside the loop 54
# outside the loop 18
# outside the loop 33
# outside the loop 69
# outside the loop 47
# outside the loop 37
# outside the loop 54
# outside the loop 195
# outside the loop 70
# outside the loop 56
# outside the loop 49
# outside the loop 36
# outside the loop 47
# outside the loop 16
# outside the loop 190
# outside the loop 55
# outside the loop 67
# outside the loop 34
# outside the loop 38
# outside the loop 16
# outside the loop 56
# outside the loop 67
# outside the loop 164
# outside the loop 35
# outside the loop 38
# outside the loop 34
# outside the loop 48
# outside the loop 14
# outside the loop 57
# outside the loop 65
# outside the loop 34
# outside the loop 38
# outside the loop 14
# outside the loop 58
# outside the loop 65
# outside the loop 35
# outside the loop 38
# outside the loop 175
# outside the loop 15
# outside the loop 61
# outside the loop 64
# outside the loop 35
# outside the loop 150
# outside the loop 39
# outside the loop 55
# outside the loop 14
# outside the loop 61
# outside the loop 64
# outside the loop 35
# outside the loop 38
# outside the loop 44
# outside the loop 57
# outside the loop 13
# outside the loop 64
# outside the loop 60
# outside the loop 39
# outside the loop 36
# outside the loop 45
# outside the loop 14
# outside the loop 26
# outside the loop 63
# outside the loop 60
# outside the loop 138
# outside the loop 36
# outside the loop 40
# outside the loop 44
# outside the loop 14
# outside the loop 61
# outside the loop 37
# outside the loop 158
# outside the loop 40
# outside the loop 43
# outside the loop 60
# outside the loop 14
# outside the loop 60
# outside the loop 63
# outside the loop 36
# outside the loop 41
# outside the loop 45
# outside the loop 14
# outside the loop 60
# outside the loop 63
# outside the loop 39
# outside the loop 148
# outside the loop 44
# outside the loop 37
# outside the loop 41
# outside the loop 13
# outside the loop 59
# outside the loop 67
# outside the loop 141
# outside the loop 38
# outside the loop 43
# outside the loop 41
# outside the loop 31
# outside the loop 14
# outside the loop 38
# outside the loop 42
# outside the loop 43
# outside the loop 65
# outside the loop 57
# outside the loop 123
# outside the loop 40
# outside the loop 59
# outside the loop 13
# outside the loop 67
# outside the loop 137
# outside the loop 134
# outside the loop 32
# outside the loop 43
# outside the loop 39
# outside the loop 43
# outside the loop 57
# outside the loop 62
# outside the loop 13
# outside the loop 67
# outside the loop 132
# outside the loop 42
# outside the loop 43
# outside the loop 38
# outside the loop 56
# outside the loop 62
# outside the loop 13
# outside the loop 68
# outside the loop 42
# outside the loop 43
# outside the loop 39
# outside the loop 56
# outside the loop 63
# outside the loop 12
# outside the loop 111
# outside the loop 69
# outside the loop 40
# outside the loop 42
# outside the loop 45
# outside the loop 56
# outside the loop 13
# outside the loop 69
# outside the loop 43
# outside the loop 33
# outside the loop 40
# outside the loop 42
# outside the loop 54
# outside the loop 13
# outside the loop 70
# outside the loop 37
# outside the loop 43
# outside the loop 33
# outside the loop 41
# outside the loop 40
# outside the loop 54
# outside the loop 13
# outside the loop 41
# outside the loop 40
# outside the loop 44
# outside the loop 72
# outside the loop 55
# outside the loop 52
# outside the loop 65
# outside the loop 12
# outside the loop 205
# outside the loop 53
# outside the loop 73
# outside the loop 116
# outside the loop 45
# outside the loop 41
# outside the loop 41
# outside the loop 12
# outside the loop 77
# outside the loop 115
# outside the loop 41
# outside the loop 41
# outside the loop 41
# outside the loop 45
# outside the loop 51
# outside the loop 11
# outside the loop 113
# outside the loop 195
# outside the loop 35
# outside the loop 40
# outside the loop 41
# outside the loop 51
# outside the loop 45
# outside the loop 191
# outside the loop 37
# outside the loop 46
# outside the loop 40
# outside the loop 41
# outside the loop 108
# outside the loop 51
# outside the loop 11
# outside the loop 108
# outside the loop 77
# outside the loop 34
# outside the loop 42
# outside the loop 184
# outside the loop 45
# outside the loop 51
# outside the loop 12
# outside the loop 78
# outside the loop 183
# outside the loop 40
# outside the loop 46
# outside the loop 101
# outside the loop 43
# outside the loop 79
# outside the loop 103
# outside the loop 177
# outside the loop 36
# outside the loop 38
# outside the loop 43
# outside the loop 47
# outside the loop 49
# outside the loop 11
# outside the loop 103
# outside the loop 79
# outside the loop 174
# outside the loop 42
# outside the loop 37
# outside the loop 49
# outside the loop 47
# outside the loop 81
# outside the loop 170
# outside the loop 43
# outside the loop 101
# outside the loop 76
# outside the loop 37
# outside the loop 99
# outside the loop 48
# outside the loop 50
# outside the loop 11
# outside the loop 82
# outside the loop 167
# outside the loop 44
# outside the loop 48
# outside the loop 76
# outside the loop 37
# outside the loop 47
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 161
# outside the loop 37
# outside the loop 43
# outside the loop 49
# outside the loop 37
# outside the loop 45
# outside the loop 36
# outside the loop 38
# outside the loop 46
# outside the loop 86
# outside the loop 48
# outside the loop 46
# outside the loop 158
# outside the loop 95
# outside the loop 49
# outside the loop 155
# outside the loop 87
# outside the loop 91
# outside the loop 39
# outside the loop 45
# outside the loop 46
# outside the loop 22
# outside the loop 151
# outside the loop 81
# outside the loop 88
# outside the loop 39
# outside the loop 48
# outside the loop 50
# outside the loop 46
# outside the loop 46
# outside the loop 39
# outside the loop 47
# outside the loop 47
# outside the loop 149
# outside the loop 50
# outside the loop 89
# outside the loop 90
# outside the loop 40
# outside the loop 52
# outside the loop 47
# outside the loop 45
# outside the loop 147
# outside the loop 87
# outside the loop 91
# outside the loop 41
# outside the loop 144
# outside the loop 47
# outside the loop 50
# outside the loop 18
# outside the loop 140
# outside the loop 81
# outside the loop 86
# outside the loop 47
# outside the loop 93
# outside the loop 41
# outside the loop 45
# outside the loop 52
# outside the loop 53
# outside the loop 31
# outside the loop 138
# outside the loop 47
# outside the loop 94
# outside the loop 41
# outside the loop 45
# outside the loop 53
# outside the loop 134
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 95
# outside the loop 49
# outside the loop 42
# outside the loop 42
# outside the loop 131
# outside the loop 81
# outside the loop 40
# outside the loop 46
# outside the loop 97
# outside the loop 41
# outside the loop 44
# outside the loop 49
# outside the loop 53
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 48
# outside the loop 32
# outside the loop 44
# outside the loop 42
# outside the loop 53
# outside the loop 55
# outside the loop 127
# outside the loop 79
# outside the loop 43
# outside the loop 43
# outside the loop 50
# outside the loop 55
# outside the loop 124
# outside the loop 77
# outside the loop 34
# outside the loop 43
# outside the loop 51
# outside the loop 20
# outside the loop 56
# outside the loop 122
# outside the loop 33
# outside the loop 43
# outside the loop 41
# outside the loop 51
# outside the loop 56
# outside the loop 120
# outside the loop 75
# outside the loop 33
# outside the loop 42
# outside the loop 43
# outside the loop 51
# outside the loop 19
# outside the loop 56
# outside the loop 117
# outside the loop 73
# outside the loop 33
# outside the loop 45
# outside the loop 52
# outside the loop 20
# outside the loop 54
# outside the loop 58
# outside the loop 116
# outside the loop 42
# outside the loop 46
# outside the loop 41
# outside the loop 46
# outside the loop 54
# outside the loop 58
# outside the loop 113
# outside the loop 71
# outside the loop 20
# outside the loop 60
# outside the loop 55
# outside the loop 111
# outside the loop 71
# outside the loop 45
# outside the loop 53
# outside the loop 35
# outside the loop 19
# outside the loop 60
# outside the loop 55
# outside the loop 109
# outside the loop 45
# outside the loop 68
# outside the loop 56
# outside the loop 108
# outside the loop 35
# outside the loop 46
# outside the loop 43
# outside the loop 60
# outside the loop 20
# outside the loop 57
# outside the loop 61
# outside the loop 106
# outside the loop 67
# outside the loop 48
# outside the loop 39
# outside the loop 57
# outside the loop 61
# outside the loop 65
# outside the loop 36
# outside the loop 103
# outside the loop 49
# outside the loop 38
# outside the loop 58
# outside the loop 102
# outside the loop 62
# outside the loop 64
# outside the loop 36
# outside the loop 50
# outside the loop 44
# outside the loop 59
# outside the loop 101
# outside the loop 62
# outside the loop 63
# outside the loop 37
# outside the loop 50
# outside the loop 63
# outside the loop 60
# outside the loop 62
# outside the loop 37
# outside the loop 99
# outside the loop 50
# outside the loop 36
# outside the loop 39
# outside the loop 50
# outside the loop 60
# outside the loop 64
# outside the loop 61
# outside the loop 97
# outside the loop 60
# outside the loop 66
# outside the loop 96
# outside the loop 35
# outside the loop 66
# outside the loop 61
# outside the loop 36
# outside the loop 94
# outside the loop 35
# outside the loop 52
# outside the loop 62
# outside the loop 63
# outside the loop 66
# outside the loop 40
# outside the loop 92
# outside the loop 52
# outside the loop 60
# outside the loop 68
# outside the loop 64
# outside the loop 91
# outside the loop 35
# outside the loop 39
# outside the loop 52
# outside the loop 63
# outside the loop 67
# outside the loop 91
# outside the loop 40
# outside the loop 34
# outside the loop 51
# outside the loop 57
# outside the loop 24
# outside the loop 64
# outside the loop 68
# outside the loop 91
# outside the loop 41
# outside the loop 88
# outside the loop 53
# outside the loop 58
# outside the loop 55
# outside the loop 58
# outside the loop 66
# outside the loop 85
# outside the loop 67
# outside the loop 34
# outside the loop 40
# outside the loop 57
# outside the loop 67
# outside the loop 69
# outside the loop 85
# outside the loop 87
# outside the loop 42
# outside the loop 45
# outside the loop 46
# outside the loop 55
# outside the loop 55
# outside the loop 72
# outside the loop 66
# outside the loop 85
# outside the loop 42
# outside the loop 55
# outside the loop 32
# outside the loop 25
# outside the loop 42
# outside the loop 54
# outside the loop 55
# outside the loop 67
# outside the loop 72
# outside the loop 83
# outside the loop 85
# outside the loop 26
# outside the loop 32
# outside the loop 82
# outside the loop 69
# outside the loop 72
# outside the loop 42
# outside the loop 52
# outside the loop 50
# outside the loop 53
# outside the loop 27
# outside the loop 32
# outside the loop 58
# outside the loop 82
# outside the loop 71
# outside the loop 74
# outside the loop 43
# outside the loop 49
# outside the loop 51
# outside the loop 58
# outside the loop 32
# outside the loop 26
# outside the loop 70
# outside the loop 79
# outside the loop 74
# outside the loop 43
# outside the loop 27
# outside the loop 30
# outside the loop 60
# outside the loop 79
# outside the loop 76
# outside the loop 70
# outside the loop 43
# outside the loop 49
# outside the loop 27
# outside the loop 61
# outside the loop 32
# outside the loop 77
# outside the loop 72
# outside the loop 76
# outside the loop 44
# outside the loop 49
# outside the loop 62
# outside the loop 26
# outside the loop 73
# outside the loop 77
# outside the loop 74
# outside the loop 45
# outside the loop 51
# outside the loop 49
# outside the loop 62
# outside the loop 46
# outside the loop 52
# outside the loop 50
# outside the loop 44
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 75
# outside the loop 29
# outside the loop 28
# outside the loop 75
# outside the loop 78
# outside the loop 75
# outside the loop 23
# outside the loop 41
# outside the loop 50
# outside the loop 47
# outside the loop 29
# outside the loop 30
# outside the loop 65
# outside the loop 74
# outside the loop 47
# outside the loop 81
# outside the loop 76
# outside the loop 29
# outside the loop 29
# outside the loop 75
# outside the loop 64
# outside the loop 77
# outside the loop 71
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 41
# outside the loop 47
# outside the loop 29
# outside the loop 30
# outside the loop 65
# outside the loop 77
# outside the loop 83
# outside the loop 33
# outside the loop 43
# outside the loop 47
# outside the loop 45
# outside the loop 29
# outside the loop 48
# outside the loop 48
# outside the loop 66
# outside the loop 29
# outside the loop 45
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 70
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 67
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 81
# outside the loop 50
# outside the loop 44
# outside the loop 31
# outside the loop 69
# outside the loop 57
# outside the loop 68
# outside the loop 81
# outside the loop 27
# outside the loop 81
# outside the loop 50
# outside the loop 43
# outside the loop 45
# outside the loop 31
# outside the loop 69
# outside the loop 67
# outside the loop 28
# outside the loop 81
# outside the loop 45
# outside the loop 51
# outside the loop 44
# outside the loop 91
# outside the loop 56
# outside the loop 31
# outside the loop 68
# outside the loop 83
# outside the loop 86
# outside the loop 51
# outside the loop 43
# outside the loop 53
# outside the loop 66
# outside the loop 26
# outside the loop 72
# outside the loop 85
# outside the loop 89
# outside the loop 43
# outside the loop 66
# outside the loop 70
# outside the loop 67
# outside the loop 33
# outside the loop 86
# outside the loop 89
# outside the loop 36
# outside the loop 53
# outside the loop 41
# outside the loop 53
# outside the loop 66
# outside the loop 32
# outside the loop 63
# outside the loop 87
# outside the loop 43
# outside the loop 93
# outside the loop 42
# outside the loop 54
# outside the loop 64
# outside the loop 32
# outside the loop 70
# outside the loop 69
# outside the loop 88
# outside the loop 43
# outside the loop 89
# outside the loop 27
# outside the loop 62
# outside the loop 71
# outside the loop 90
# outside the loop 33
# outside the loop 53
# outside the loop 41
# outside the loop 28
# outside the loop 55
# outside the loop 83
# outside the loop 92
# outside the loop 34
# outside the loop 41
# outside the loop 28
# outside the loop 63
# outside the loop 56
# outside the loop 34
# outside the loop 37
# outside the loop 41
# outside the loop 93
# outside the loop 57
# outside the loop 17
# outside the loop 36
# outside the loop 38
# outside the loop 96
# outside the loop 35
# outside the loop 41
# outside the loop 30
# outside the loop 60
# outside the loop 78
# outside the loop 35
# outside the loop 37
# outside the loop 41
# outside the loop 97
# outside the loop 59
# outside the loop 29
# outside the loop 60
# outside the loop 35
# outside the loop 77
# outside the loop 38
# outside the loop 39
# outside the loop 59
# outside the loop 58
# outside the loop 30
# outside the loop 36
# outside the loop 37
# outside the loop 77
# outside the loop 100
# outside the loop 39
# outside the loop 30
# outside the loop 58
# outside the loop 78
# outside the loop 79
# outside the loop 102
# outside the loop 37
# outside the loop 40
# outside the loop 37
# outside the loop 30
# outside the loop 61
# outside the loop 81
# outside the loop 82
# outside the loop 36
# outside the loop 104
# outside the loop 39
# outside the loop 37
# outside the loop 62
# outside the loop 40
# outside the loop 37
# outside the loop 195
# outside the loop 31
# outside the loop 105
# outside the loop 82
# outside the loop 83
# outside the loop 22
# outside the loop 15
# outside the loop 30
# outside the loop 107
# outside the loop 61
# outside the loop 83
# outside the loop 192
# outside the loop 37
# outside the loop 38
# outside the loop 30
# outside the loop 62
# outside the loop 108
# outside the loop 185
# outside the loop 86
# outside the loop 86
# outside the loop 38
# outside the loop 37
# outside the loop 38
# outside the loop 64
# outside the loop 30
# outside the loop 110
# outside the loop 180
# outside the loop 85
# outside the loop 37
# outside the loop 39
# outside the loop 20
# outside the loop 54
# outside the loop 31
# outside the loop 64
# outside the loop 16
# outside the loop 114
# outside the loop 33
# outside the loop 87
# outside the loop 177
# outside the loop 89
# outside the loop 39
# outside the loop 53
# outside the loop 66
# outside the loop 115
# outside the loop 63
# outside the loop 172
# outside the loop 88
# outside the loop 39
# outside the loop 41
# outside the loop 91
# outside the loop 31
# outside the loop 116
# outside the loop 164
# outside the loop 90
# outside the loop 42
# outside the loop 92
# outside the loop 53
# outside the loop 35
# outside the loop 41
# outside the loop 67
# outside the loop 41
# outside the loop 53
# outside the loop 31
# outside the loop 163
# outside the loop 119
# outside the loop 91
# outside the loop 95
# outside the loop 67
# outside the loop 30
# outside the loop 121
# outside the loop 160
# outside the loop 154
# outside the loop 92
# outside the loop 41
# outside the loop 41
# outside the loop 52
# outside the loop 50
# outside the loop 68
# outside the loop 154
# outside the loop 94
# outside the loop 41
# outside the loop 50
# outside the loop 40
# outside the loop 70
# outside the loop 148
# outside the loop 95
# outside the loop 42
# outside the loop 43
# outside the loop 50
# outside the loop 43
# outside the loop 31
# outside the loop 51
# outside the loop 18
# outside the loop 70
# outside the loop 41
# outside the loop 153
# outside the loop 96
# outside the loop 71
# outside the loop 140
# outside the loop 97
# outside the loop 43
# outside the loop 43
# outside the loop 50
# outside the loop 138
# outside the loop 98
# outside the loop 43
# outside the loop 43
# outside the loop 49
# outside the loop 101
# outside the loop 73
# outside the loop 86
# outside the loop 42
# outside the loop 48
# outside the loop 22
# outside the loop 12
# outside the loop 132
# outside the loop 104
# outside the loop 45
# outside the loop 47
# outside the loop 43
# outside the loop 105
# outside the loop 132
# outside the loop 48
# outside the loop 45
# outside the loop 45
# outside the loop 12
# outside the loop 17
# outside the loop 107
# outside the loop 128
# outside the loop 46
# outside the loop 45
# outside the loop 46
# outside the loop 12
# outside the loop 107
# outside the loop 45
# outside the loop 44
# outside the loop 46
# outside the loop 18
# outside the loop 109
# outside the loop 123
# outside the loop 45
# outside the loop 45
# outside the loop 48
# outside the loop 46
# outside the loop 48
# outside the loop 112
# outside the loop 45
# outside the loop 122
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 112
# outside the loop 120
# outside the loop 47
# outside the loop 45
# outside the loop 116
# outside the loop 81
# outside the loop 117
# outside the loop 46
# outside the loop 43
# outside the loop 48
# outside the loop 12
# outside the loop 81
# outside the loop 117
# outside the loop 115
# outside the loop 43
# outside the loop 47
# outside the loop 33
# outside the loop 119
# outside the loop 113
# outside the loop 85
# outside the loop 100
# outside the loop 47
# outside the loop 43
# outside the loop 83
# outside the loop 111
# outside the loop 102
# outside the loop 43
# outside the loop 47
# outside the loop 15
# outside the loop 43
# outside the loop 51
# outside the loop 46
# outside the loop 34
# outside the loop 85
# outside the loop 107
# outside the loop 28
# outside the loop 35
# outside the loop 107
# outside the loop 86
# outside the loop 41
# outside the loop 47
# outside the loop 88
# outside the loop 50
# outside the loop 103
# outside the loop 37
# outside the loop 41
# outside the loop 208
# outside the loop 90
# outside the loop 101
# outside the loop 41
# outside the loop 49
# outside the loop 93
# outside the loop 98
# outside the loop 90
# outside the loop 28
# outside the loop 41
# outside the loop 50
# outside the loop 37
# outside the loop 11
# outside the loop 57
# outside the loop 28
# outside the loop 93
# outside the loop 96
# outside the loop 39
# outside the loop 50
# outside the loop 56
# outside the loop 28
# outside the loop 96
# outside the loop 92
# outside the loop 40
# outside the loop 51
# outside the loop 56
# outside the loop 28
# outside the loop 96
# outside the loop 94
# outside the loop 93
# outside the loop 38
# outside the loop 51
# outside the loop 52
# outside the loop 93
# outside the loop 39
# outside the loop 75
# outside the loop 202
# outside the loop 99
# outside the loop 91
# outside the loop 40
# outside the loop 52
# outside the loop 56
# outside the loop 66
# outside the loop 37
# outside the loop 199
# outside the loop 90
# outside the loop 98
# outside the loop 39
# outside the loop 58
# outside the loop 53
# outside the loop 54
# outside the loop 62
# outside the loop 171
# outside the loop 90
# outside the loop 39
# outside the loop 54
# outside the loop 105
# outside the loop 58
# outside the loop 190
# outside the loop 86
# outside the loop 37
# outside the loop 61
# outside the loop 55
# outside the loop 36
# outside the loop 187
# outside the loop 85
# outside the loop 39
# outside the loop 35
# outside the loop 36
# outside the loop 55
# outside the loop 107
# outside the loop 83
# outside the loop 182
# outside the loop 36
# outside the loop 59
# outside the loop 57
# outside the loop 109
# outside the loop 64
# outside the loop 35
# outside the loop 39
# outside the loop 81
# outside the loop 35
# outside the loop 37
# outside the loop 42
# outside the loop 55
# outside the loop 35
# outside the loop 57
# outside the loop 110
# outside the loop 174
# outside the loop 83
# outside the loop 61
# outside the loop 112
# outside the loop 35
# outside the loop 64
# outside the loop 171
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 35
# outside the loop 43
# outside the loop 57
# outside the loop 58
# outside the loop 115
# outside the loop 168
# outside the loop 65
# outside the loop 34
# outside the loop 79
# outside the loop 40
# outside the loop 59
# outside the loop 66
# outside the loop 165
# outside the loop 116
# outside the loop 34
# outside the loop 77
# outside the loop 41
# outside the loop 36
# outside the loop 60
# outside the loop 76
# outside the loop 119
# outside the loop 68
# outside the loop 75
# outside the loop 65
# outside the loop 163
# outside the loop 41
# outside the loop 37
# outside the loop 44
# outside the loop 60
# outside the loop 70
# outside the loop 121
# outside the loop 65
# outside the loop 75
# outside the loop 34
# outside the loop 37
# outside the loop 44
# outside the loop 61
# outside the loop 124
# outside the loop 157
# outside the loop 74
# outside the loop 41
# outside the loop 38
# outside the loop 64
# outside the loop 72
# outside the loop 154
# outside the loop 61
# outside the loop 126
# outside the loop 73
# outside the loop 37
# outside the loop 34
# outside the loop 44
# outside the loop 64
# outside the loop 150
# outside the loop 73
# outside the loop 148
# outside the loop 93
# outside the loop 44
# outside the loop 157
# outside the loop 64
# outside the loop 149
# outside the loop 71
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 44
# outside the loop 62
# outside the loop 65
# outside the loop 31
# outside the loop 75
# outside the loop 145
# outside the loop 70
# outside the loop 83
# outside the loop 40
# outside the loop 46
# outside the loop 63
# outside the loop 65
# outside the loop 144
# outside the loop 68
# outside the loop 44
# outside the loop 39
# outside the loop 82
# outside the loop 67
# outside the loop 31
# outside the loop 67
# outside the loop 77
# outside the loop 63
# outside the loop 139
# outside the loop 45
# outside the loop 85
# outside the loop 39
# outside the loop 94
# outside the loop 66
# outside the loop 78
# outside the loop 67
# outside the loop 139
# outside the loop 45
# outside the loop 47
# outside the loop 137
# outside the loop 67
# outside the loop 65
# outside the loop 134
# outside the loop 46
# outside the loop 86
# outside the loop 81
# outside the loop 41
# outside the loop 29
# outside the loop 67
# outside the loop 63
# outside the loop 81
# outside the loop 134
# outside the loop 131
# outside the loop 42
# outside the loop 89
# outside the loop 46
# outside the loop 69
# outside the loop 131
# outside the loop 82
# outside the loop 63
# outside the loop 66
# outside the loop 47
# outside the loop 42
# outside the loop 29
# outside the loop 70
# outside the loop 129
# outside the loop 83
# outside the loop 47
# outside the loop 92
# outside the loop 42
# outside the loop 61
# outside the loop 70
# outside the loop 127
# outside the loop 83
# outside the loop 40
# outside the loop 47
# outside the loop 56
# outside the loop 61
# outside the loop 72
# outside the loop 60
# outside the loop 124
# outside the loop 40
# outside the loop 48
# outside the loop 94
# outside the loop 43
# outside the loop 29
# outside the loop 73
# outside the loop 124
# outside the loop 122
# outside the loop 40
# outside the loop 48
# outside the loop 43
# outside the loop 56
# outside the loop 120
# outside the loop 58
# outside the loop 88
# outside the loop 40
# outside the loop 44
# outside the loop 49
# outside the loop 119
# outside the loop 40
# outside the loop 89
# outside the loop 43
# outside the loop 49
# outside the loop 56
# outside the loop 117
# outside the loop 40
# outside the loop 92
# outside the loop 51
# outside the loop 54
# outside the loop 65
# outside the loop 114
# outside the loop 46
# outside the loop 51
# outside the loop 92
# outside the loop 54
# outside the loop 27
# outside the loop 114
# outside the loop 94
# outside the loop 46
# outside the loop 51
# outside the loop 54
# outside the loop 27
# outside the loop 112
# outside the loop 85
# outside the loop 45
# outside the loop 94
# outside the loop 51
# outside the loop 54
# outside the loop 26
# outside the loop 110
# outside the loop 87
# outside the loop 46
# outside the loop 52
# outside the loop 52
# outside the loop 26
# outside the loop 108
# outside the loop 46
# outside the loop 98
# outside the loop 53
# outside the loop 53
# outside the loop 79
# outside the loop 107
# outside the loop 43
# outside the loop 47
# outside the loop 51
# outside the loop 54
# outside the loop 48
# outside the loop 52
# outside the loop 105
# outside the loop 54
# outside the loop 52
# outside the loop 106
# outside the loop 104
# outside the loop 48
# outside the loop 102
# outside the loop 55
# outside the loop 55
# outside the loop 102
# outside the loop 107
# outside the loop 97
# outside the loop 48
# outside the loop 101
# outside the loop 50
# outside the loop 24
# outside the loop 56
# outside the loop 101
# outside the loop 109
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 97
# outside the loop 50
# outside the loop 49
# outside the loop 57
# outside the loop 112
# outside the loop 50
# outside the loop 99
# outside the loop 49
# outside the loop 23
# outside the loop 57
# outside the loop 114
# outside the loop 51
# outside the loop 86
# outside the loop 97
# outside the loop 50
# outside the loop 96
# outside the loop 24
# outside the loop 58
# outside the loop 115
# outside the loop 51
# outside the loop 97
# outside the loop 50
# outside the loop 24
# outside the loop 117
# outside the loop 59
# outside the loop 96
# outside the loop 47
# outside the loop 51
# outside the loop 120
# outside the loop 53
# outside the loop 93
# outside the loop 88
# outside the loop 47
# outside the loop 46
# outside the loop 59
# outside the loop 53
# outside the loop 122
# outside the loop 61
# outside the loop 87
# outside the loop 93
# outside the loop 48
# outside the loop 54
# outside the loop 126
# outside the loop 59
# outside the loop 92
# outside the loop 45
# outside the loop 89
# outside the loop 55
# outside the loop 61
# outside the loop 91
# outside the loop 56
# outside the loop 63
# outside the loop 45
# outside the loop 89
# outside the loop 44
# outside the loop 21
# outside the loop 55
# outside the loop 62
# outside the loop 88
# outside the loop 205
# outside the loop 96
# outside the loop 46
# outside the loop 43
# outside the loop 57
# outside the loop 22
# outside the loop 65
# outside the loop 41
# outside the loop 87
# outside the loop 44
# outside the loop 93
# outside the loop 19
# outside the loop 22
# outside the loop 64
# outside the loop 193
# outside the loop 85
# outside the loop 43
# outside the loop 97
# outside the loop 56
# outside the loop 19
# outside the loop 99
# outside the loop 43
# outside the loop 57
# outside the loop 64
# outside the loop 84
# outside the loop 187
# outside the loop 58
# outside the loop 19
# outside the loop 21
# outside the loop 204
# outside the loop 65
# outside the loop 84
# outside the loop 44
# outside the loop 20
# outside the loop 58
# outside the loop 196
# outside the loop 69
# outside the loop 81
# outside the loop 43
# outside the loop 66
# outside the loop 19
# outside the loop 60
# outside the loop 67
# outside the loop 193
# outside the loop 82
# outside the loop 42
# outside the loop 20
# outside the loop 62
# outside the loop 20
# outside the loop 67
# outside the loop 188
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 41
# outside the loop 19
# outside the loop 20
# outside the loop 61
# outside the loop 184
# outside the loop 79
# outside the loop 70
# outside the loop 177
# outside the loop 19
# outside the loop 42
# outside the loop 61
# outside the loop 78
# outside the loop 69
# outside the loop 176
# outside the loop 29
# outside the loop 36
# outside the loop 19
# outside the loop 61
# outside the loop 172
# outside the loop 70
# outside the loop 77
# outside the loop 38
# outside the loop 29
# outside the loop 63
# outside the loop 77
# outside the loop 167
# outside the loop 76
# outside the loop 29
# outside the loop 68
# outside the loop 35
# outside the loop 63
# outside the loop 163
# outside the loop 74
# outside the loop 37
# outside the loop 75
# outside the loop 19
# outside the loop 22
# outside the loop 64
# outside the loop 158
# outside the loop 75
# outside the loop 76
# outside the loop 33
# outside the loop 71
# outside the loop 63
# outside the loop 157
# outside the loop 74
# outside the loop 35
# outside the loop 71
# outside the loop 27
# outside the loop 74
# outside the loop 66
# outside the loop 73
# outside the loop 75
# outside the loop 153
# outside the loop 36
# outside the loop 21
# outside the loop 19
# outside the loop 67
# outside the loop 73
# outside the loop 150
# ...
# outside the loop 162
# outside the loop 81
# outside the loop 50
# outside the loop 104
# outside the loop 29
# outside the loop 50
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 160
# outside the loop 24
# outside the loop 30
# outside the loop 50
# outside the loop 78
# outside the loop 157
# outside the loop 12
# outside the loop 50
# outside the loop 77
# outside the loop 108
# outside the loop 153
# outside the loop 12
# outside the loop 22
# outside the loop 30
# outside the loop 152
# outside the loop 111
# outside the loop 75
# outside the loop 49
# outside the loop 76
# outside the loop 112
# outside the loop 149
# outside the loop 29
# outside the loop 139
# outside the loop 48
# outside the loop 19
# outside the loop 31
# outside the loop 74
# outside the loop 116
# outside the loop 146
# outside the loop 137
# outside the loop 40
# outside the loop 47
# outside the loop 74
# outside the loop 31
# outside the loop 142
# outside the loop 117
# outside the loop 72
# outside the loop 40
# outside the loop 47
# outside the loop 74
# outside the loop 22
# outside the loop 142
# outside the loop 118
# outside the loop 70
# outside the loop 48
# outside the loop 72
# outside the loop 121
# outside the loop 137
# outside the loop 133
# outside the loop 46
# outside the loop 71
# outside the loop 32
# outside the loop 69
# outside the loop 135
# outside the loop 45
# outside the loop 32
# outside the loop 46
# outside the loop 70
# outside the loop 132
# outside the loop 125
# outside the loop 69
# outside the loop 130
# outside the loop 127
# outside the loop 33
# outside the loop 46
# outside the loop 67
# outside the loop 129
# outside the loop 32
# outside the loop 125
# outside the loop 34
# outside the loop 45
# outside the loop 68
# outside the loop 65
# outside the loop 126
# outside the loop 44
# outside the loop 43
# outside the loop 17
# outside the loop 123
# outside the loop 115
# outside the loop 33
# outside the loop 43
# outside the loop 64
# outside the loop 122
# outside the loop 34
# outside the loop 43
# outside the loop 65
# outside the loop 113
# outside the loop 35
# outside the loop 43
# outside the loop 64
# outside the loop 18
# outside the loop 119
# outside the loop 17
# outside the loop 35
# outside the loop 62
# outside the loop 46
# outside the loop 117
# outside the loop 204
# outside the loop 62
# outside the loop 115
# outside the loop 35
# outside the loop 199
# outside the loop 41
# outside the loop 61
# outside the loop 58
# outside the loop 109
# outside the loop 42
# outside the loop 35
# outside the loop 40
# outside the loop 59
# outside the loop 193
# outside the loop 113
# outside the loop 42
# outside the loop 48
# outside the loop 59
# outside the loop 184
# outside the loop 110
# outside the loop 36
# outside the loop 57
# outside the loop 106
# outside the loop 37
# outside the loop 41
# outside the loop 17
# outside the loop 57
# outside the loop 106
# outside the loop 56
# outside the loop 183
# outside the loop 35
# outside the loop 104
# outside the loop 37
# outside the loop 55
# outside the loop 14
# outside the loop 101
# outside the loop 187
# outside the loop 56
# outside the loop 16
# outside the loop 177
# outside the loop 100
# outside the loop 54
# outside the loop 17
# outside the loop 174
# outside the loop 99
# outside the loop 53
# outside the loop 15
# outside the loop 175
# outside the loop 97
# outside the loop 35
# outside the loop 95
# outside the loop 166
# outside the loop 53
# outside the loop 94
# outside the loop 161
# outside the loop 52
# outside the loop 38
# outside the loop 49
# outside the loop 16
# outside the loop 156
# outside the loop 51
# outside the loop 37
# outside the loop 92
# outside the loop 37
# outside the loop 51
# outside the loop 90
# outside the loop 47
# outside the loop 156
# outside the loop 14
# outside the loop 88
# outside the loop 153
# outside the loop 50
# outside the loop 47
# outside the loop 49
# outside the loop 89
# outside the loop 12
# outside the loop 87
# outside the loop 144
# outside the loop 32
# outside the loop 48
# outside the loop 13
# outside the loop 85
# outside the loop 47
# outside the loop 140
# outside the loop 85
# outside the loop 46
# outside the loop 13
# outside the loop 83
# outside the loop 138
# outside the loop 47
# outside the loop 12
# outside the loop 83
# outside the loop 135
# outside the loop 43
# outside the loop 46
# outside the loop 81
# outside the loop 135
# outside the loop 122
# outside the loop 34
# outside the loop 45
# outside the loop 13
# outside the loop 129
# outside the loop 79
# outside the loop 45
# outside the loop 12
# outside the loop 79
# outside the loop 128
# outside the loop 78
# outside the loop 44
# outside the loop 42
# outside the loop 77
# outside the loop 123
# outside the loop 43
# outside the loop 76
# outside the loop 121
# outside the loop 45
# outside the loop 43
# outside the loop 12
# outside the loop 76
# outside the loop 43
# outside the loop 46
# outside the loop 12
# outside the loop 73
# outside the loop 43
# outside the loop 11
# outside the loop 42
# outside the loop 76
# outside the loop 113
# outside the loop 72
# outside the loop 72
# outside the loop 40
# outside the loop 76
# outside the loop 72
# outside the loop 42
# outside the loop 43
# outside the loop 11
# outside the loop 70
# outside the loop 45
# outside the loop 10
# outside the loop 69
# outside the loop 40
# outside the loop 67
# outside the loop 67
# outside the loop 48
# outside the loop 68
# outside the loop 39
# outside the loop 50
# outside the loop 100
# outside the loop 29
# outside the loop 65
# outside the loop 29
# outside the loop 65
# outside the loop 65
# outside the loop 51
# outside the loop 65
# outside the loop 50
# outside the loop 28
# outside the loop 212
# outside the loop 64
# outside the loop 36
# outside the loop 49
# outside the loop 63
# outside the loop 208
# outside the loop 49
# outside the loop 60
# outside the loop 192
# outside the loop 81
# outside the loop 48
# outside the loop 59
# outside the loop 67
# outside the loop 185
# outside the loop 51
# outside the loop 59
# outside the loop 54
# outside the loop 183
# outside the loop 59
# outside the loop 177
# outside the loop 50
# outside the loop 60
# outside the loop 173
# outside the loop 182
# outside the loop 52
# outside the loop 59
# outside the loop 177
# outside the loop 52
# outside the loop 57
# outside the loop 166
# outside the loop 52
# outside the loop 57
# outside the loop 20
# outside the loop 75
# outside the loop 61
# outside the loop 163
# outside the loop 52
# outside the loop 20
# outside the loop 61
# outside the loop 162
# outside the loop 53
# outside the loop 20
# outside the loop 155
# outside the loop 55
# outside the loop 54
# outside the loop 56
# outside the loop 158
# outside the loop 54
# outside the loop 211
# outside the loop 56
# outside the loop 146
# outside the loop 207
# outside the loop 57
# outside the loop 142
# outside the loop 200
# outside the loop 56
# outside the loop 57
# outside the loop 24
# outside the loop 196
# outside the loop 56
# outside the loop 60
# outside the loop 136
# outside the loop 191
# outside the loop 62
# outside the loop 64
# outside the loop 186
# outside the loop 57
# outside the loop 63
# outside the loop 168
# outside the loop 128
# outside the loop 181
# outside the loop 53
# outside the loop 22
# outside the loop 178
# outside the loop 60
# outside the loop 21
# outside the loop 22
# outside the loop 173
# outside the loop 125
# outside the loop 62
# outside the loop 54
# outside the loop 21
# outside the loop 168
# outside the loop 62
# outside the loop 53
# outside the loop 21
# outside the loop 63
# outside the loop 164
# outside the loop 21
# outside the loop 22
# outside the loop 67
# outside the loop 161
# outside the loop 52
# outside the loop 63
# outside the loop 21
# outside the loop 22
# outside the loop 67
# outside the loop 157
# outside the loop 64
# outside the loop 51
# outside the loop 100
# outside the loop 65
# outside the loop 154
# outside the loop 49
# outside the loop 103
# outside the loop 150
# outside the loop 65
# outside the loop 49
# outside the loop 104
# outside the loop 22
# outside the loop 67
# outside the loop 147
# outside the loop 71
# outside the loop 143
# outside the loop 66
# outside the loop 108
# outside the loop 47
# outside the loop 23
# outside the loop 19
# outside the loop 68
# outside the loop 139
# outside the loop 48
# outside the loop 20
# outside the loop 137
# outside the loop 68
# outside the loop 47
# outside the loop 113
# outside the loop 20
# outside the loop 134
# outside the loop 47
# outside the loop 20
# outside the loop 74
# outside the loop 131
# outside the loop 70
# outside the loop 20
# outside the loop 128
# outside the loop 69
# outside the loop 20
# outside the loop 126
# outside the loop 71
# outside the loop 20
# outside the loop 124
# outside the loop 72
# outside the loop 20
# outside the loop 208
# outside the loop 119
# outside the loop 72
# outside the loop 19
# outside the loop 202
# outside the loop 117
# outside the loop 72
# outside the loop 18
# outside the loop 116
# outside the loop 92
# outside the loop 197
# outside the loop 123
# outside the loop 190
# outside the loop 113
# outside the loop 75
# outside the loop 90
# outside the loop 186
# outside the loop 111
# outside the loop 76
# outside the loop 18
# outside the loop 119
# outside the loop 182
# outside the loop 109
# outside the loop 86
# outside the loop 77
# outside the loop 108
# outside the loop 108
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 176
# outside the loop 18
# outside the loop 82
# outside the loop 116
# outside the loop 172
# outside the loop 106
# outside the loop 166
# outside the loop 81
# outside the loop 102
# outside the loop 101
# outside the loop 163
# outside the loop 83
# outside the loop 154
# outside the loop 18
# outside the loop 111
# outside the loop 157
# outside the loop 82
# outside the loop 99
# outside the loop 17
# outside the loop 82
# outside the loop 156
# outside the loop 98
# outside the loop 17
# outside the loop 152
# outside the loop 96
# outside the loop 107
# outside the loop 149
# outside the loop 95
# outside the loop 87
# outside the loop 144
# outside the loop 178
# outside the loop 85
# outside the loop 92
# outside the loop 29
# outside the loop 141
# outside the loop 93
# outside the loop 103
# outside the loop 29
# outside the loop 139
# outside the loop 90
# outside the loop 29
# outside the loop 135
# outside the loop 88
# outside the loop 90
# outside the loop 102
# outside the loop 29
# outside the loop 87
# outside the loop 132
# outside the loop 96
# outside the loop 96
# outside the loop 129
# outside the loop 86
# outside the loop 79
# outside the loop 127
# outside the loop 85
# outside the loop 98
# outside the loop 124
# outside the loop 84
# outside the loop 99
# outside the loop 122
# outside the loop 187
# outside the loop 83
# outside the loop 97
# outside the loop 99
# outside the loop 119
# outside the loop 82
# outside the loop 184
# outside the loop 78
# outside the loop 95
# outside the loop 207
# outside the loop 117
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 79
# outside the loop 203
# outside the loop 15
# outside the loop 114
# outside the loop 79
# outside the loop 198
# outside the loop 13
# outside the loop 31
# outside the loop 113
# outside the loop 77
# outside the loop 174
# outside the loop 195
# outside the loop 78
# outside the loop 110
# outside the loop 190
# outside the loop 79
# outside the loop 14
# outside the loop 108
# outside the loop 76
# outside the loop 32
# outside the loop 131
# outside the loop 184
# outside the loop 78
# outside the loop 162
# outside the loop 75
# outside the loop 104
# outside the loop 131
# outside the loop 181
# outside the loop 78
# outside the loop 32
# outside the loop 73
# outside the loop 128
# outside the loop 79
# outside the loop 175
# outside the loop 88
# outside the loop 104
# outside the loop 102
# outside the loop 73
# outside the loop 79
# outside the loop 171
# outside the loop 13
# outside the loop 71
# outside the loop 167
# outside the loop 79
# outside the loop 100
# outside the loop 14
# outside the loop 70
# outside the loop 162
# outside the loop 79
# outside the loop 169
# outside the loop 99
# outside the loop 70
# outside the loop 156
# outside the loop 79
# outside the loop 84
# outside the loop 97
# outside the loop 68
# outside the loop 164
# outside the loop 156
# outside the loop 79
# outside the loop 95
# outside the loop 68
# outside the loop 151
# outside the loop 79
# outside the loop 162
# outside the loop 117
# outside the loop 34
# outside the loop 94
# outside the loop 67
# outside the loop 158
# outside the loop 147
# outside the loop 79
# outside the loop 34
# outside the loop 92
# outside the loop 66
# outside the loop 35
# outside the loop 144
# outside the loop 155
# outside the loop 79
# outside the loop 90
# outside the loop 211
# outside the loop 35
# outside the loop 140
# outside the loop 79
# outside the loop 90
# outside the loop 63
# outside the loop 207
# outside the loop 35
# outside the loop 151
# outside the loop 137
# outside the loop 79
# outside the loop 87
# outside the loop 35
# outside the loop 135
# outside the loop 131
# outside the loop 79
# outside the loop 199
# outside the loop 87
# outside the loop 62
# outside the loop 132
# outside the loop 194
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 85
# outside the loop 34
# outside the loop 36
# outside the loop 128
# outside the loop 84
# outside the loop 191
# outside the loop 127
# outside the loop 141
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 36
# outside the loop 127
# outside the loop 82
# outside the loop 143
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 186
# outside the loop 36
# outside the loop 81
# outside the loop 123
# outside the loop 185
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 37
# outside the loop 59
# outside the loop 182
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 121
# outside the loop 79
# outside the loop 37
# outside the loop 78
# outside the loop 178
# outside the loop 119
# outside the loop 134
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 37
# outside the loop 37
# outside the loop 134
# outside the loop 78
# outside the loop 116
# outside the loop 176
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 38
# outside the loop 172
# outside the loop 76
# outside the loop 131
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 130
# outside the loop 76
# outside the loop 113
# outside the loop 169
# outside the loop 79
# outside the loop 40
# outside the loop 55
# outside the loop 74
# outside the loop 169
# outside the loop 161
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 40
# outside the loop 37
# outside the loop 104
# outside the loop 74
# outside the loop 109
# outside the loop 163
# outside the loop 125
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 39
# outside the loop 87
# outside the loop 72
# outside the loop 105
# outside the loop 162
# outside the loop 122
# outside the loop 154
# outside the loop 79
# outside the loop 71
# outside the loop 156
# outside the loop 79
# outside the loop 101
# outside the loop 71
# outside the loop 101
# outside the loop 155
# outside the loop 79
# outside the loop 41
# outside the loop 70
# outside the loop 153
# outside the loop 78
# outside the loop 42
# outside the loop 51
# outside the loop 98
# outside the loop 68
# outside the loop 41
# outside the loop 150
# outside the loop 78
# outside the loop 96
# outside the loop 67
# outside the loop 147
# outside the loop 79
# outside the loop 42
# outside the loop 95
# outside the loop 66
# outside the loop 147
# outside the loop 79
# outside the loop 79
# outside the loop 96
# outside the loop 65
# outside the loop 143
# outside the loop 79
# outside the loop 92
# outside the loop 26
# outside the loop 64
# outside the loop 211
# outside the loop 142
# outside the loop 79
# outside the loop 79
# outside the loop 91
# outside the loop 207
# outside the loop 62
# outside the loop 139
# outside the loop 79
# outside the loop 129
# outside the loop 79
# outside the loop 44
# outside the loop 62
# outside the loop 135
# outside the loop 203
# outside the loop 79
# outside the loop 44
# outside the loop 87
# outside the loop 107
# outside the loop 62
# outside the loop 134
# outside the loop 199
# outside the loop 126
# outside the loop 79
# outside the loop 79
# outside the loop 43
# outside the loop 60
# outside the loop 132
# outside the loop 193
# outside the loop 78
# outside the loop 83
# outside the loop 46
# outside the loop 59
# outside the loop 131
# outside the loop 191
# outside the loop 79
# outside the loop 85
# outside the loop 58
# outside the loop 128
# outside the loop 70
# outside the loop 82
# outside the loop 184
# outside the loop 79
# outside the loop 58
# outside the loop 128
# outside the loop 183
# outside the loop 80
# inside the loop
#
#
#  80
# outside the loop 77
# outside the loop 46
# outside the loop 58
# outside the loop 125
# outside the loop 181
# outside the loop 113
# outside the loop 79
# outside the loop 76
# outside the loop 45
